# %% [markdown]
# # Data Preparation Stage

# %%
# importing necessary modules

import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import math
import scipy.stats
from scipy.stats import beta

# %%
# setting up directions

direct = 'data'
curr = os.getcwd()
PATH = os.path.join(curr, direct)
os.chdir(PATH)

# %%
files = os.listdir()

# %%
def extract_csvs(files_list):
    """
    helps extracting data to one, concatenated DF from multiple csv files.
    """
    frames = []
    for file in files_list:
        df = pd.read_csv(file, header=0, sep=";", engine='python')
        frames.append(df)
    if len(frames) == len(files):
        print('Extracting validated')
        final_df = pd.concat(frames, ignore_index=True)
        return final_df
    else:
        print('Number of DataFrames is not matching number of files passed as an argument!')
        return None

# %%
main_df = extract_csvs(files)
# Out:
# Extracting validated

# %%
# dropping columns that we are not going to use in further analysis

cropped_df = main_df.drop(['Event', 'Method', 'Referee', 'Round', 'Time'], axis=1)

# %%
# changing values in event_date column to datetypes

cropped_df['Event_date'] = pd.to_datetime(cropped_df['Event_date'])

# %%
cropped_df
# Out:
#                    Fighter          Opponent Result Event_date
# 0      Shamil Abdurakhimov    Curtis Blaydes   loss 2019-09-07
# 1      Shamil Abdurakhimov     Marcin Tybura    win 2019-04-20
# 2      Shamil Abdurakhimov   Andrei Arlovski    win 2018-09-15
# 3      Shamil Abdurakhimov     Chase Sherman    win 2017-11-25
# 4      Shamil Abdurakhimov     Derrick Lewis   loss 2016-12-09
# ...                    ...               ...    ...        ...
# 12091        Julianna Pena       Sarah Moras   loss 2012-04-19
# 12092        Julianna Pena    Rachael Swatez    win 2011-12-15
# 12093        Julianna Pena  Stephanie Webber    win 2009-12-05
# 12094        Julianna Pena       Robyn Dunne    win 2009-08-15
# 12095        Julianna Pena    Raylene Harvey    win 2009-05-09
#
# [12096 rows x 4 columns]

# %%
cropped_df = cropped_df[cropped_df['Result'] != 'NC']

# %%
# creating dataframe that contains pairs of current UFC fighters that have fought against each other

def get_pairs(df):
    """
    function that enables to create pairs containing only ufc fighters that have fought against each other.
    """
    ufc_fighters = df['Fighter'].unique()
    df_pairs = df.copy()
    for index, row in df_pairs.iterrows():
        if row['Opponent'] not in ufc_fighters:
            df_pairs.drop(index, inplace=True)
    return df_pairs

# %%
pairs_df = get_pairs(cropped_df)

# %%
pairs_df
# Out:
#                    Fighter              Opponent Result Event_date
# 0      Shamil Abdurakhimov        Curtis Blaydes   loss 2019-09-07
# 1      Shamil Abdurakhimov         Marcin Tybura    win 2019-04-20
# 2      Shamil Abdurakhimov       Andrei Arlovski    win 2018-09-15
# 3      Shamil Abdurakhimov         Chase Sherman    win 2017-11-25
# 4      Shamil Abdurakhimov         Derrick Lewis   loss 2016-12-09
# ...                    ...                   ...    ...        ...
# 12064          Weili Zhang          Tecia Torres    win 2019-03-02
# 12084        Julianna Pena         Nicco Montano    win 2019-07-13
# 12085        Julianna Pena  Valentina Shevchenko   loss 2017-01-28
# 12087        Julianna Pena           Jessica Eye    win 2015-10-03
# 12091        Julianna Pena           Sarah Moras   loss 2012-04-19
#
# [3117 rows x 4 columns]

# %%
def filter_unique_pairs(df):
    """
    function that filters through previously created pairs to filter out duplicates;
    for instance: fighter_A vs fighter_B is a duplicate of fighter_B vs fighter_A
    and out initial dataframe contains both fights, since they were collected from the perspective
    of two fighters.
    """
    df_unique = df.copy()
    uniques = []
    for index, row in df_unique.iterrows():
        if (row['Fighter'], row['Opponent']) in uniques:
            df_unique.drop(index, inplace=True)
        else:
            if (row['Opponent'], row['Fighter']) in uniques:
                df_unique.drop(index, inplace=True)
            else:
                uniques.append((row['Fighter'], row['Opponent']))
    return df_unique

# %%
unique_pairs_df = filter_unique_pairs(pairs_df)

# %%
unique_pairs_df
# Out:
#                          Fighter           Opponent Result Event_date
# 0            Shamil Abdurakhimov     Curtis Blaydes   loss 2019-09-07
# 1            Shamil Abdurakhimov      Marcin Tybura    win 2019-04-20
# 2            Shamil Abdurakhimov    Andrei Arlovski    win 2018-09-15
# 3            Shamil Abdurakhimov      Chase Sherman    win 2017-11-25
# 4            Shamil Abdurakhimov      Derrick Lewis   loss 2016-12-09
# ...                          ...                ...    ...        ...
# 11884  Maia Kahaunaele-Stevenson      Polyana Viana   loss 2018-02-03
# 11918               Tecia Torres        Weili Zhang   loss 2019-03-02
# 11921               Tecia Torres  Michelle Waterson    win 2017-12-02
# 11930               Tecia Torres      Paige VanZant    win 2013-01-05
# 11945              Paige VanZant  Michelle Waterson   loss 2016-12-17
#
# [1471 rows x 4 columns]

# %%
def extract_common_opps(unique_pairs_df, df):
    """
    function that matches common opponents for each pair and creates separated dataframes based on that.
    """
    temp = []
    for index, row in unique_pairs_df.iterrows():
        condition_A = df['Fighter'] == row['Fighter']
        condition_B = df['Fighter'] == row['Opponent']
        A_frame = df[condition_A]
        B_frame = df[condition_B]
        opps_B = B_frame['Opponent'].tolist()
        opps_A = A_frame['Opponent'].tolist()
        query1 = (A_frame['Opponent'].isin(opps_B))
        query2 = (B_frame['Opponent'].isin(opps_A))
        fights_A = A_frame[query1]
        fights_B = B_frame[query2]
        head_pair = A_frame[A_frame['Opponent'] == row['Opponent']]
        final = pd.concat([head_pair, fights_A, fights_B], ignore_index=True)
        temp.append(final)
    return temp

# %%
temp = extract_common_opps(unique_pairs_df, cropped_df)

# %%
def discard_frames_without_common_ops(temp_list):
    """
    function that discards groups which are not containing any common opponents.
    """
    product = []
    for group in temp_list:
        if len(group) > 1:
            product.append(group)
    return product

# %%
groups = discard_frames_without_common_ops(temp)

# %%
groups
# Out:
# [               Fighter         Opponent Result Event_date
#  0  Shamil Abdurakhimov    Marcin Tybura    win 2019-04-20
#  1  Shamil Abdurakhimov  Andrei Arlovski    win 2018-09-15
#  2  Shamil Abdurakhimov    Derrick Lewis   loss 2016-12-09
#  3  Shamil Abdurakhimov  Timothy Johnson   loss 2015-04-04
#  4        Marcin Tybura    Derrick Lewis   loss 2018-02-18
#  5        Marcin Tybura  Andrei Arlovski    win 2017-06-17
#  6        Marcin Tybura  Timothy Johnson   loss 2016-04-10,
#                 Fighter         Opponent Result Event_date
#  0  Shamil Abdurakhimov  Andrei Arlovski    win 2018-09-15
#  1  Shamil Abdurakhimov    Marcin Tybura    win 2019-04-20
#  5  Urijah Faber  Mike Thomas Brown   loss 2009-06-07
#  6  Urijah Faber  Mike Thomas Brown   loss 2008-11-05,
#          Fighter         Opponent Result Event_date
#  0     Jose Aldo      Cub Swanson    win 2009-06-07
#  1     Jose Aldo  Renato Carneiro    win 2019-02-02
#  2     Jose Aldo  Jeremy Stephens    win 2018-07-28
#  3     Jose Aldo     Max Holloway   loss 2017-12-02
#  4     Jose Aldo     Max Holloway   loss 2017-06-03
#  5     Jose Aldo    Frankie Edgar    win 2016-07-09
#  6     Jose Aldo      Chad Mendes    win 2014-10-25
#  7     Jose Aldo    Ricardo Lamas    win 2014-02-01
#  8     Jose Aldo    Frankie Edgar    win 2013-02-02
#  9     Jose Aldo      Chad Mendes    win 2012-01-14
#  10  Cub Swanson  Renato Carneiro   loss 2018-08-04
#  11  Cub Swanson    Frankie Edgar   loss 2018-04-21
#  12  Cub Swanson     Max Holloway   loss 2015-04-18
#  13  Cub Swanson    Frankie Edgar   loss 2014-11-22
#  14  Cub Swanson  Jeremy Stephens    win 2014-06-28
#  15  Cub Swanson    Ricardo Lamas   loss 2011-11-12
#  16  Cub Swanson      Chad Mendes   loss 2010-08-18,
#           Fighter           Opponent Result Event_date
#  0  Brendan Allen      Kevin Holland    win 2019-10-18
#  1  Brendan Allen  Anthony Hernandez   loss 2018-01-26
#  2  Kevin Holland  Anthony Hernandez    win 2020-05-16,
#               Fighter           Opponent Result Event_date
#  0      Brendan Allen  Anthony Hernandez   loss 2018-01-26
#  1      Brendan Allen      Kevin Holland    win 2019-10-18
#  2  Anthony Hernandez      Kevin Holland   loss 2020-05-16,
#           Fighter     Opponent Result Event_date
#  0  Brendan Allen  Eryk Anders   loss 2017-06-23
#  1  Brendan Allen     Jon Kirk    win 2017-02-10
#  2    Eryk Anders     Jon Kirk    win 2017-03-10,
#           Fighter      Opponent Result Event_date
#  0  Brendan Allen  Trevin Giles   loss 2016-03-25
#  1  Brendan Allen   Larry Crowe    win 2018-06-22
#  2   Trevin Giles   Larry Crowe    win 2015-10-09,
#            Fighter        Opponent Result Event_date
#  0   Eddie Alvarez  Dustin Poirier   loss 2018-07-28
#  1   Eddie Alvarez  Justin Gaethje    win 2017-12-02
#  2   Eddie Alvarez  Conor McGregor   loss 2016-11-12
#  3   Eddie Alvarez  Anthony Pettis    win 2016-01-17
#  4  Dustin Poirier  Justin Gaethje    win 2018-04-14
#  5  Dustin Poirier  Anthony Pettis    win 2017-11-11
#  6  Dustin Poirier  Conor McGregor   loss 2014-09-27,
#            Fighter        Opponent Result Event_date
#  0   Eddie Alvarez  Justin Gaethje    win 2017-12-02
#  1   Eddie Alvarez  Dustin Poirier   loss 2018-07-28
#  2   Eddie Alvarez  Donald Cerrone   loss 2014-09-27
#  3  Justin Gaethje  Donald Cerrone    win 2019-09-14
#  4  Justin Gaethje  Dustin Poirier   loss 2018-04-14,
#            Fighter        Opponent Result Event_date
#  0   Eddie Alvarez  Conor McGregor   loss 2016-11-12
#  1   Eddie Alvarez  Dustin Poirier   loss 2018-07-28
#  2   Eddie Alvarez  Donald Cerrone   loss 2014-09-27
#  3  Conor McGregor  Donald Cerrone    win 2020-01-18
#  4  Conor McGregor  Dustin Poirier    win 2014-09-27,
#              Fighter          Opponent Result Event_date
#  0     Eddie Alvarez  Rafael dos Anjos    win 2016-07-07
#  1     Eddie Alvarez    Anthony Pettis    win 2016-01-17
#  2     Eddie Alvarez    Donald Cerrone   loss 2014-09-27
#  3  Rafael dos Anjos    Donald Cerrone    win 2015-12-19
#  4  Rafael dos Anjos    Anthony Pettis    win 2015-03-14
#  5  Rafael dos Anjos    Donald Cerrone    win 2013-08-28,
#            Fighter          Opponent Result Event_date
#  0   Eddie Alvarez    Anthony Pettis    win 2016-01-17
#  1   Eddie Alvarez    Dustin Poirier   loss 2018-07-28
#  2   Eddie Alvarez  Rafael dos Anjos    win 2016-07-07
#  3   Eddie Alvarez  Gilbert Melendez    win 2015-06-13
#  4   Eddie Alvarez    Donald Cerrone   loss 2014-09-27
#  5  Anthony Pettis    Donald Cerrone    win 2020-05-09
#  6  Anthony Pettis    Dustin Poirier   loss 2017-11-11
#  7  Anthony Pettis  Rafael dos Anjos   loss 2015-03-14
#  8  Anthony Pettis  Gilbert Melendez    win 2014-12-06
#  9  Anthony Pettis    Donald Cerrone    win 2013-01-26,
#             Fighter          Opponent Result Event_date
#  0    Eddie Alvarez    Donald Cerrone   loss 2014-09-27
#  1    Eddie Alvarez    Justin Gaethje    win 2017-12-02
#  2    Eddie Alvarez    Conor McGregor   loss 2016-11-12
#  3    Eddie Alvarez  Rafael dos Anjos    win 2016-07-07
#  4    Eddie Alvarez    Anthony Pettis    win 2016-01-17
#  5   Donald Cerrone    Anthony Pettis   loss 2020-05-09
#  6   Donald Cerrone    Conor McGregor   loss 2020-01-18
#  7   Donald Cerrone    Justin Gaethje   loss 2019-09-14
#  8   Donald Cerrone  Rafael dos Anjos   loss 2015-12-19
#  9   Donald Cerrone  Rafael dos Anjos   loss 2013-08-28
#  10  Donald Cerrone    Anthony Pettis   loss 2013-01-26,
#           Fighter         Opponent Result Event_date
#  0  Warlley Alves      Randy Brown   loss 2019-11-16
#  1  Warlley Alves  Bryan Barberena   loss 2016-05-14
#  2    Randy Brown  Bryan Barberena    win 2019-06-22,
#           Fighter       Opponent Result Event_date
#  0  Warlley Alves  Sergio Moraes    win 2019-05-11
#  1  Warlley Alves   James Krause   loss 2018-08-25
#  2  Warlley Alves   Kamaru Usman   loss 2016-11-19
#  3  Sergio Moraes   James Krause   loss 2019-11-16
#  4  Sergio Moraes   Kamaru Usman   loss 2017-09-16,
#           Fighter       Opponent Result Event_date
#  0  Warlley Alves   James Krause   loss 2018-08-25
#  1  Warlley Alves  Sergio Moraes    win 2019-05-11
#  2   James Krause  Sergio Moraes    win 2019-11-16,
#           Fighter         Opponent Result Event_date
#  0  Warlley Alves     Kamaru Usman   loss 2016-11-19
#  1  Warlley Alves    Sergio Moraes    win 2019-05-11
#  2  Warlley Alves  Colby Covington    win 2015-12-12
#  3   Kamaru Usman  Colby Covington    win 2019-12-14
#  4   Kamaru Usman    Sergio Moraes    win 2017-09-16,
#             Fighter         Opponent Result Event_date
#  0    Warlley Alves  Bryan Barberena   loss 2016-05-14
#  1    Warlley Alves      Randy Brown   loss 2019-11-16
#  2    Warlley Alves  Colby Covington    win 2015-12-12
#  3  Bryan Barberena      Randy Brown   loss 2019-06-22
#  4  Bryan Barberena  Colby Covington   loss 2016-12-17,
#             Fighter         Opponent Result Event_date
#  0    Warlley Alves  Colby Covington    win 2015-12-12
#  1    Warlley Alves     Kamaru Usman   loss 2016-11-19
#  2    Warlley Alves  Bryan Barberena   loss 2016-05-14
#  3  Colby Covington     Kamaru Usman   loss 2019-12-14
#  4  Colby Covington  Bryan Barberena    win 2016-12-17,
#        Fighter                  Opponent Result Event_date
#  0   Sam Alvey                Ryan Spann   loss 2020-05-09
#  1   Sam Alvey  Antonio Rogerio Nogueira   loss 2018-09-22
#  2   Sam Alvey            Alex Nicholson    win 2016-11-05
#  3  Ryan Spann  Antonio Rogerio Nogueira    win 2019-05-11
#  4  Ryan Spann            Alex Nicholson    win 2018-01-26,
#                      Fighter                  Opponent Result Event_date
#  0                 Sam Alvey  Antonio Rogerio Nogueira   loss 2018-09-22
#  1                 Sam Alvey                Ryan Spann   loss 2020-05-09
#  2                 Sam Alvey              Rashad Evans    win 2017-08-05
#  3  Antonio Rogerio Nogueira                Ryan Spann   loss 2019-05-11
#  4  Antonio Rogerio Nogueira              Rashad Evans    win 2013-02-02,
#          Fighter            Opponent Result Event_date
#  0     Sam Alvey        Eric Spicely    win 2016-07-13
#  1     Sam Alvey  Gerald Meerschaert    win 2014-05-31
#  2     Sam Alvey  Gerald Meerschaert   loss 2010-09-11
#  3  Eric Spicely  Gerald Meerschaert   loss 2017-12-01,
#           Fighter         Opponent Result Event_date
#  0      Sam Alvey    Derek Brunson   loss 2015-08-08
#  1      Sam Alvey  Elias Theodorou   loss 2016-06-18
#  2      Sam Alvey     Daniel Kelly    win 2015-05-10
#  3  Derek Brunson  Elias Theodorou    win 2019-05-04
#  4  Derek Brunson     Daniel Kelly    win 2017-06-10,
#            Fighter         Opponent Result Event_date
#  0       Sam Alvey   Cezar Ferreira    win 2015-02-22
#  1       Sam Alvey   Nate Marquardt    win 2017-01-28
#  2       Sam Alvey  Elias Theodorou   loss 2016-06-18
#  3       Sam Alvey   Elvis Mutapcic   loss 2013-02-15
#  4  Cezar Ferreira   Nate Marquardt    win 2017-11-11
#  5  Cezar Ferreira  Elias Theodorou   loss 2017-02-19
#  6  Cezar Ferreira   Elvis Mutapcic   loss 2011-08-20,
#                Fighter            Opponent Result Event_date
#  0           Sam Alvey  Gerald Meerschaert    win 2014-05-31
#  1           Sam Alvey  Gerald Meerschaert   loss 2010-09-11
#  2           Sam Alvey        Eric Spicely    win 2016-07-13
#  3           Sam Alvey        Eddie Larrea    win 2012-01-07
#  4  Gerald Meerschaert        Eric Spicely    win 2017-12-01
#  5  Gerald Meerschaert        Eddie Larrea    win 2014-01-31
#  6  Gerald Meerschaert        Eddie Larrea    win 2012-09-06
#  7  Gerald Meerschaert        Eddie Larrea    win 2010-03-20,
#                Fighter            Opponent Result Event_date
#  0         Eryk Anders  Gerald Meerschaert    win 2019-10-12
#  1         Eryk Anders       Thiago Santos   loss 2018-09-22
#  2  Gerald Meerschaert       Thiago Santos   loss 2017-07-08,
#            Fighter         Opponent Result Event_date
#  0  Corey Anderson   Jan Blachowicz   loss 2020-02-15
#  1  Corey Anderson   Jan Blachowicz    win 2015-09-05
#  2  Corey Anderson      Ilir Latifi    win 2018-12-29
#  3  Corey Anderson  Patrick Cummins    win 2018-04-21
#  4  Corey Anderson      Jimi Manuwa   loss 2017-03-18
#  5  Jan Blachowicz      Jimi Manuwa    win 2018-03-17
#  6  Jan Blachowicz  Patrick Cummins   loss 2017-04-08
#  7  Jan Blachowicz      Jimi Manuwa   loss 2015-04-11
#  8  Jan Blachowicz      Ilir Latifi    win 2014-10-04,
#            Fighter          Opponent Result Event_date
#  0  Corey Anderson       Ilir Latifi    win 2018-12-29
#  1  Corey Anderson    Jan Blachowicz   loss 2020-02-15
#  2  Corey Anderson  Ovince St. Preux   loss 2017-11-04
#  3  Corey Anderson    Sean O'Connell    win 2016-12-09
#  4  Corey Anderson    Jan Blachowicz    win 2015-09-05
#  5  Corey Anderson     Gian Villante   loss 2015-04-18
#  6     Ilir Latifi  Ovince St. Preux    win 2018-02-24
#  7     Ilir Latifi     Gian Villante    win 2016-03-05
#  8     Ilir Latifi    Sean O'Connell    win 2016-01-17
#  9     Ilir Latifi    Jan Blachowicz   loss 2014-10-04,
#             Fighter          Opponent Result Event_date
#  0   Corey Anderson   Glover Teixeira    win 2018-07-22
#  1   Corey Anderson   Patrick Cummins    win 2018-04-21
#  2   Corey Anderson  Ovince St. Preux   loss 2017-11-04
#  3   Corey Anderson   Fabio Maldonado    win 2015-11-07
#  4  Glover Teixeira   Patrick Cummins    win 2015-11-07
#  5  Glover Teixeira  Ovince St. Preux    win 2015-08-08
#  6  Glover Teixeira   Fabio Maldonado    win 2012-10-13,
#               Fighter          Opponent Result Event_date
#  0     Corey Anderson  Ovince St. Preux   loss 2017-11-04
#  1     Corey Anderson       Ilir Latifi    win 2018-12-29
#  2     Corey Anderson   Glover Teixeira    win 2018-07-22
#  3     Corey Anderson   Patrick Cummins    win 2018-04-21
#  4     Corey Anderson       Jimi Manuwa   loss 2017-03-18
#  5     Corey Anderson      Mauricio Rua   loss 2016-05-14
#  6     Corey Anderson     Gian Villante   loss 2015-04-18
#  7   Ovince St. Preux       Ilir Latifi   loss 2018-02-24
#  8   Ovince St. Preux       Jimi Manuwa   loss 2016-10-08
#  9   Ovince St. Preux   Glover Teixeira   loss 2015-08-08
#  10  Ovince St. Preux   Patrick Cummins    win 2015-04-18
#  11  Ovince St. Preux      Mauricio Rua    win 2014-11-08
#  12  Ovince St. Preux     Gian Villante    win 2013-04-27,
#            Fighter          Opponent Result Event_date
#  0  Corey Anderson      Mauricio Rua   loss 2016-05-14
#  1  Corey Anderson  Ovince St. Preux   loss 2017-11-04
#  2  Corey Anderson     Gian Villante   loss 2015-04-18
#  0  Raphael Assuncao      Bryan Caraway    win 2014-10-04
#  1  Raphael Assuncao  Aljamain Sterling    win 2017-01-28
#  2  Raphael Assuncao       Pedro Munhoz    win 2014-02-22
#  3     Bryan Caraway       Pedro Munhoz   loss 2018-11-30
#  4     Bryan Caraway  Aljamain Sterling    win 2016-05-29,
#              Fighter           Opponent Result Event_date
#  0  Raphael Assuncao       Pedro Munhoz    win 2014-02-22
#  1  Raphael Assuncao           Rob Font    win 2018-07-07
#  2  Raphael Assuncao  Aljamain Sterling    win 2017-01-28
#  3  Raphael Assuncao      Bryan Caraway    win 2014-10-04
#  4  Raphael Assuncao        Jeff Curran   loss 2006-11-11
#  5      Pedro Munhoz  Aljamain Sterling   loss 2019-06-08
#  6      Pedro Munhoz      Bryan Caraway    win 2018-11-30
#  7      Pedro Munhoz           Rob Font    win 2017-10-28
#  8      Pedro Munhoz        Jeff Curran    win 2013-08-16,
#              Fighter        Opponent Result Event_date
#  0  Raphael Assuncao       Erik Koch   loss 2011-03-19
#  1  Raphael Assuncao  Jameel Massouh    win 2009-04-05
#  2  Raphael Assuncao     Joe Pearson    win 2008-11-08
#  3         Erik Koch  Jameel Massouh    win 2009-12-19
#  4         Erik Koch     Joe Pearson    win 2008-04-05,
#              Fighter      Opponent Result Event_date
#  0  Raphael Assuncao  Urijah Faber   loss 2010-01-10
#  1  Raphael Assuncao   Joe Pearson    win 2008-11-08
#  2  Raphael Assuncao   Jeff Curran   loss 2006-11-11
#  3      Urijah Faber   Jeff Curran    win 2007-12-12
#  4      Urijah Faber   Joe Pearson    win 2007-01-20,
#              Fighter        Opponent Result Event_date
#  0  Raphael Assuncao      Joe Lauzon    win 2006-02-18
#  1  Raphael Assuncao  Jorge Masvidal    win 2005-04-21
#  2        Joe Lauzon  Jorge Masvidal   loss 2005-04-30,
#              Fighter         Opponent Result Event_date
#  0  Raphael Assuncao   Jorge Masvidal    win 2005-04-21
#  1  Raphael Assuncao       Joe Lauzon    win 2006-02-18
#  2  Raphael Assuncao  Brandon Bledsoe    win 2005-02-04
#  3    Jorge Masvidal       Joe Lauzon    win 2005-04-30
#  4    Jorge Masvidal  Brandon Bledsoe    win 2003-05-24,
#          Fighter        Opponent Result Event_date
#  0  Jessin Ayari      Steven Ray   loss 2018-10-27
#  1  Jessin Ayari  Mickael Lebout    win 2016-04-16
#  2    Steven Ray  Mickael Lebout    win 2015-10-24,
#             Fighter       Opponent Result Event_date
#  0  Bryan Barberena    Randy Brown   loss 2019-06-22
#  1  Bryan Barberena  Warlley Alves    win 2016-05-14
#  2      Randy Brown  Warlley Alves    win 2019-11-16,
#             Fighter       Opponent Result Event_date
#  0  Bryan Barberena  Vicente Luque   loss 2019-02-17
#  1  Bryan Barberena   Leon Edwards   loss 2017-09-02
#  2  Bryan Barberena   Chad Laprise   loss 2015-04-25
#  3    Vicente Luque   Chad Laprise    win 2018-05-19
#  4    Vicente Luque   Leon Edwards   loss 2017-03-18,
#             Fighter       Opponent Result Event_date
#  0  Bryan Barberena   Leon Edwards   loss 2017-09-02
#  1  Bryan Barberena  Vicente Luque   loss 2019-02-17
#  2     Leon Edwards  Vicente Luque    win 2017-03-18,
#             Fighter         Opponent Result Event_date
#  0  Bryan Barberena  Colby Covington   loss 2016-12-17
#  1  Bryan Barberena    Warlley Alves    win 2016-05-14
#  2  Colby Covington    Warlley Alves   loss 2015-12-12,
#             Fighter       Opponent Result Event_date
#  0  Bryan Barberena   Chad Laprise   loss 2015-04-25
#  1  Bryan Barberena  Vicente Luque   loss 2019-02-17
#  2     Chad Laprise  Vicente Luque   loss 2018-05-19,
#           Fighter        Opponent Result Event_date
#  0  Edson Barboza     Paul Felder   loss 2019-09-07
#  1  Edson Barboza     Paul Felder    win 2015-07-25
#  2  Edson Barboza      Dan Hooker    win 2018-12-15
#  3  Edson Barboza  Danny Castillo    win 2013-12-14
#  4  Edson Barboza    Ross Pearson    win 2011-08-27
#  5    Paul Felder      Dan Hooker   loss 2020-02-23
#  6    Paul Felder    Ross Pearson   loss 2015-09-05
#  7    Paul Felder  Danny Castillo    win 2015-01-03,
#            Fighter         Opponent Result Event_date
#  0   Edson Barboza   Justin Gaethje   loss 2019-03-30
#  1   Edson Barboza    Tony Ferguson   loss 2015-12-11
#  2   Edson Barboza  Michael Johnson   loss 2015-02-22
#  3   Edson Barboza   Donald Cerrone   loss 2014-04-19
#  4  Justin Gaethje    Tony Ferguson    win 2020-05-09
#  5  Justin Gaethje   Donald Cerrone    win 2019-09-14
#  6  Justin Gaethje  Michael Johnson    win 2017-07-07,
#           Fighter      Opponent Result Event_date
#  0  Edson Barboza    Dan Hooker    win 2018-12-15
#  1  Edson Barboza   Paul Felder   loss 2019-09-07
#  2  Edson Barboza   Paul Felder    win 2015-07-25
#  3  Edson Barboza  Ross Pearson    win 2011-08-27
#  4     Dan Hooker   Paul Felder    win 2020-02-23
#  5     Dan Hooker  Ross Pearson    win 2017-06-10,
#           Fighter       Opponent Result Event_date
#  0  Edson Barboza      Kevin Lee   loss 2018-04-21
#  1  Edson Barboza  Tony Ferguson   loss 2015-12-11
#  2      Kevin Lee  Tony Ferguson   loss 2017-10-07,
#                 Fighter             Opponent Result Event_date
#  0        Edson Barboza  Khabib Nurmagomedov   loss 2017-12-30
#  1        Edson Barboza      Michael Johnson   loss 2015-02-22
#  2  Khabib Nurmagomedov      Michael Johnson    win 2016-11-12,
#            Fighter         Opponent Result Event_date
#  0   Edson Barboza   Beneil Dariush    win 2017-03-11
#  1   Edson Barboza  Michael Johnson   loss 2015-02-22
#  2   Edson Barboza      Evan Dunham    win 2014-07-16
#  3  Beneil Dariush      Evan Dunham   draw 2017-10-07
#  4  Beneil Dariush  Michael Johnson    win 2015-08-08,
#            Fighter          Opponent Result Event_date
#  0   Edson Barboza    Anthony Pettis    win 2016-04-23
#  1   Edson Barboza  Gilbert Melendez    win 2016-07-23
#  2   Edson Barboza     Tony Ferguson   loss 2015-12-11
#  3   Edson Barboza    Donald Cerrone   loss 2014-04-19
#  4   Edson Barboza    Danny Castillo    win 2013-12-14
#  12  Donald Cerrone    Anthony Pettis   loss 2013-01-26
#  13  Donald Cerrone      Jamie Varner    win 2010-09-30
#  14  Donald Cerrone      Jamie Varner   loss 2009-01-25
#  15  Donald Cerrone    Danny Castillo    win 2008-06-01
#  16  Donald Cerrone  Anthony Njokuani    win 2007-04-28,
#             Fighter           Opponent Result Event_date
#  0  Enrique Barzola    Gabriel Benitez    win 2017-05-13
#  1  Enrique Barzola  Humberto Bandenay    win 2014-04-16
#  2  Gabriel Benitez  Humberto Bandenay    win 2018-05-19,
#           Fighter       Opponent Result Event_date
#  0  Mirsad Bektic    Josh Emmett   loss 2019-07-13
#  1  Mirsad Bektic  Ricardo Lamas    win 2018-06-09
#  2    Josh Emmett  Ricardo Lamas    win 2017-12-16,
#           Fighter       Opponent Result Event_date
#  0  Mirsad Bektic  Ricardo Lamas    win 2018-06-09
#  1  Mirsad Bektic    Josh Emmett   loss 2019-07-13
#  2  Mirsad Bektic  Darren Elkins   loss 2017-03-04
#  3  Ricardo Lamas  Darren Elkins    win 2018-11-17
#  4  Ricardo Lamas    Josh Emmett   loss 2017-12-16,
#           Fighter          Opponent Result Event_date
#  0  Mirsad Bektic     Darren Elkins   loss 2017-03-04
#  1  Mirsad Bektic     Ricardo Lamas    win 2018-06-09
#  2  Mirsad Bektic  Godofredo Castro    win 2018-01-27
#  3  Mirsad Bektic     Lucas Martins    win 2015-05-30
#  4  Mirsad Bektic       Chas Skelly    win 2014-04-19
#  5  Darren Elkins     Ricardo Lamas   loss 2018-11-17
#  6  Darren Elkins  Godofredo Castro    win 2016-07-23
#  7  Darren Elkins       Chas Skelly    win 2016-03-05
#  8  Darren Elkins     Lucas Martins    win 2014-10-25,
#           Fighter       Opponent Result Event_date
#  0  Mirsad Bektic    Chas Skelly    win 2014-04-19
#  1  Mirsad Bektic  Darren Elkins   loss 2017-03-04
#  2    Chas Skelly  Darren Elkins   loss 2016-03-05,
#                 Fighter             Opponent Result Event_date
#  0     Joseph Benavidez  Deiveson Figueiredo   loss 2020-02-29
#  1     Joseph Benavidez      Jussier Formiga    win 2019-06-29
#  2     Joseph Benavidez          John Moraga    win 2015-05-23
#  3     Joseph Benavidez          Tim Elliott    win 2014-04-26
#  4     Joseph Benavidez      Jussier Formiga    win 2013-09-04
#  5  Deiveson Figueiredo          Tim Elliott    win 2019-10-12
#  6  Deiveson Figueiredo      Jussier Formiga   loss 2019-03-23
#  7  Deiveson Figueiredo          John Moraga    win 2018-08-25,
#               Fighter             Opponent Result Event_date
#  0   Joseph Benavidez      Jussier Formiga    win 2019-06-29
#  1   Joseph Benavidez      Jussier Formiga    win 2013-09-04
#  2   Joseph Benavidez  Deiveson Figueiredo   loss 2020-02-29
#  3   Joseph Benavidez         Dustin Ortiz    win 2019-01-19
#  4   Joseph Benavidez        Sergio Pettis   loss 2018-06-09
#  5   Joseph Benavidez         Henry Cejudo    win 2016-12-03
#  6   Joseph Benavidez        Zach Makovsky    win 2016-02-06
#  7   Joseph Benavidez         Dustin Ortiz    win 2014-11-22
#  8   Joseph Benavidez           Ian McCall    win 2013-02-02
#  5   Paige VanZant       Tecia Torres   loss 2013-01-05,
#                Fighter              Opponent Result Event_date
#  0        Amanda Nunes     Raquel Pennington    win 2018-05-12
#  1        Amanda Nunes  Germaine de Randamie    win 2019-12-14
#  2        Amanda Nunes            Holly Holm    win 2019-07-06
#  3        Amanda Nunes           Miesha Tate    win 2016-07-09
#  4        Amanda Nunes           Cat Zingano   loss 2014-09-27
#  5        Amanda Nunes  Germaine de Randamie    win 2013-11-06
#  6        Amanda Nunes       Raquel Pa'aluhi    win 2012-07-28
#  7   Raquel Pennington            Holly Holm   loss 2020-01-18
#  8   Raquel Pennington  Germaine de Randamie   loss 2018-11-10
#  9   Raquel Pennington           Miesha Tate    win 2016-11-12
#  10  Raquel Pennington            Holly Holm   loss 2015-02-28
#  11  Raquel Pennington           Cat Zingano   loss 2012-10-06
#  12  Raquel Pennington       Raquel Pa'aluhi    win 2012-09-08,
#                  Fighter              Opponent Result Event_date
#  0          Amanda Nunes  Valentina Shevchenko    win 2017-09-09
#  1          Amanda Nunes  Valentina Shevchenko    win 2016-03-05
#  2          Amanda Nunes            Holly Holm    win 2019-07-06
#  3  Valentina Shevchenko            Holly Holm    win 2016-07-23,
#               Fighter            Opponent Result Event_date
#  0      Jessica Penne   Michelle Waterson   loss 2013-04-05
#  1      Jessica Penne  Joanna Jedrzejczyk   loss 2015-06-20
#  2      Jessica Penne       Angela Magana    win 2009-09-25
#  3      Jessica Penne         Alicia Gumm    win 2008-11-08
#  4  Michelle Waterson  Joanna Jedrzejczyk   loss 2019-10-12
#  5  Michelle Waterson       Angela Magana    win 2015-07-12
#  6  Michelle Waterson         Alicia Gumm   loss 2007-06-30,
#                   Fighter        Opponent Result Event_date
#  0  Lara Fritzen Procopio      Karol Rosa   loss 2019-08-31
#  1  Lara Fritzen Procopio      Sidy Rocha    win 2018-08-24
#  2  Lara Fritzen Procopio  Mariana Morais    win 2018-03-17
#  3             Karol Rosa      Sidy Rocha    win 2017-07-01
#  4             Karol Rosa  Mariana Morais    win 2016-12-17,
#           Fighter           Opponent Result Event_date
#  0   Amanda Ribas      Polyana Viana   loss 2015-11-28
#  1   Amanda Ribas  Aline Sattelmayer    win 2015-04-11
#  2  Polyana Viana  Aline Sattelmayer   loss 2014-12-13,
#                  Fighter       Opponent Result Event_date
#  0  Valentina Shevchenko  Julianna Pena    win 2017-01-28
#  1  Valentina Shevchenko    Jessica Eye    win 2019-06-08
#  2         Julianna Pena    Jessica Eye    win 2015-10-03,
#          Fighter            Opponent Result Event_date
#  0  Tecia Torres         Weili Zhang   loss 2019-03-02
#  1  Tecia Torres  Joanna Jedrzejczyk   loss 2018-07-28
#  2  Tecia Torres     Jessica Andrade   loss 2018-02-24
#  3   Weili Zhang  Joanna Jedrzejczyk    win 2020-03-07
#  4   Weili Zhang     Jessica Andrade    win 2019-08-31,
#                Fighter            Opponent Result Event_date
#  0        Tecia Torres   Michelle Waterson    win 2017-12-02
#  1        Tecia Torres  Joanna Jedrzejczyk   loss 2018-07-28
#  2        Tecia Torres      Rose Namajunas   loss 2016-04-16
#  3        Tecia Torres       Angela Magana    win 2014-12-12
#  4        Tecia Torres       Felice Herrig    win 2013-12-07
#  5        Tecia Torres      Rose Namajunas    win 2013-07-13
#  6        Tecia Torres       Paige VanZant    win 2013-01-05
#  7   Michelle Waterson  Joanna Jedrzejczyk   loss 2019-10-12
#  8   Michelle Waterson       Felice Herrig    win 2018-10-06
#  9   Michelle Waterson      Rose Namajunas   loss 2017-04-15
#  10  Michelle Waterson       Paige VanZant    win 2016-12-17
#  11  Michelle Waterson       Angela Magana    win 2015-07-12,
#           Fighter           Opponent Result Event_date
#  0   Tecia Torres      Paige VanZant    win 2013-01-05
#  1   Tecia Torres  Michelle Waterson    win 2017-12-02
#  2   Tecia Torres       Bec Rawlings    win 2017-02-04
#  3   Tecia Torres     Rose Namajunas   loss 2016-04-16
#  4   Tecia Torres      Felice Herrig    win 2013-12-07
#  5   Tecia Torres     Rose Namajunas    win 2013-07-13
#  6  Paige VanZant  Michelle Waterson   loss 2016-12-17
#  7  Paige VanZant       Bec Rawlings    win 2016-08-27
#  8  Paige VanZant     Rose Namajunas   loss 2015-12-10
#  9  Paige VanZant      Felice Herrig    win 2015-04-18,
#               Fighter           Opponent Result Event_date
#  0      Paige VanZant  Michelle Waterson   loss 2016-12-17
#  1      Paige VanZant     Rose Namajunas   loss 2015-12-10
#  2      Paige VanZant      Felice Herrig    win 2015-04-18
#  3      Paige VanZant       Tecia Torres   loss 2013-01-05
#  4  Michelle Waterson      Felice Herrig    win 2018-10-06
#  5  Michelle Waterson       Tecia Torres   loss 2017-12-02
#  6  Michelle Waterson     Rose Namajunas   loss 2017-04-15]

# %%
def create_triples(groups):
    """
    function that creates triples; each triple contains information about the fight between fighter A and fighter B
    and information about fights with common opponent.
    """
    triples = []
    for group in groups:
        fighter_A = group['Fighter'][0]
        fighter_B = group['Opponent'][0]
        uniques = []
        for index, row in group.iterrows():
            base = group.head(1)
            if (row['Fighter'] == fighter_A) and (row['Opponent'] != fighter_B):
                if row['Opponent'] not in uniques:
                    opp = row['Opponent']
                    condition = (group['Opponent'] == opp)
                    legs = group[condition]
                    t = pd.concat([base, legs], ignore_index=True)
                    triples.append(t)
    return triples

# %%
triples = create_triples(groups)

# %%
def add_triple_rating(triples):
    """
    function that will add Rating column based on the Result for convenience in further calculations
    """
    mapping = {
        'loss': 0,
        'draw': 1,
        'win': 2,
    }
    for triple in triples:
        triple['Rating'] = triple['Result'].map(mapping)

# %%
add_triple_rating(triples)

# %%
def triple_value_validation(triple):
    """
    helper function that will assign 1 if triple is containing valuable information and 0 otherwise
    """
    results = triple['Result']
    if results[0] == 'win' or results[0] == 'loss':
        if results[1] != results[2]:
            return 1
        else:
            return 0
    else:
        return 0
    
def triple_date_validation(triple):
    """
    helper function that will assign 1 if triple is valid in terms of chronology and 0 otherwise.
    """
    head_date = triple['Event_date'][0]
    if head_date > triple['Event_date'][1] and head_date > triple['Event_date'][2]:
        return 1
    else:
        return 0

def multiple_date_validation(triple):
    """
    helper function that will return a valid triple in terms of dates if possible, otherwise it will return None.
    """
    head_date = triple['Event_date'][0]
    fighter_A = triple['Fighter'][0]
    fighter_B = triple['Opponent'][0]
    A_cond = triple[triple['Fighter'] == fighter_A]
    B_cond = triple[triple['Fighter'] == fighter_B]
    A_slice = A_cond[A_cond['Event_date'] < head_date]
    B_slice = B_cond[B_cond['Event_date'] < head_date]
    if len(A_slice) != 0 and len(B_slice) != 0:
        base = triple.head(1)
        legs = pd.concat([A_slice, B_slice], ignore_index=True)
        valid_triple = pd.concat([base, legs], ignore_index=True)
        return valid_triple
    else:
        return None

def multiple_value_validation(triple):
    """
    helper function that will assign 1 if extended triple is containing valuable information and 0 otherwise.
    """
    if triple['Result'][0] == 'win' or triple['Result'][0] == 'loss':
        truncated_triple = triple[1:]
        fighter_A = triple['Fighter'][0]
        fighter_B = triple['Opponent'][0]
        A_slice = truncated_triple[truncated_triple['Fighter'] == fighter_A]
        B_slice = truncated_triple[truncated_triple['Fighter'] == fighter_B]
    
        if len(A_slice['Result'].value_counts()) > 1 or len(B_slice['Result'].value_counts() > 1):
            if A_slice['Rating'].mean() != B_slice['Rating'].mean():
                return 1
            else:
                return 0
        else:
            if A_slice['Result'][0] != B_slice['Result'][0]:
                return 1
            else:
                return 0
    else:
        return 0

# %%
def triple_analysis(triples):
    """
    function that does triple analysis and extracts only valid triples, either they are standard - 3 elements triples
    or extended ones.
    """
    std_valid_triples = []
    ext_valid_triples = []
    for triple in triples:
        if len(triple) == 3:
            if triple_date_validation(triple) == 1:
                if triple_value_validation(triple) == 1:
                    std_valid_triples.append(triple)
        else:
            validated_triple = multiple_date_validation(triple)
            if validated_triple is not None:
                if multiple_value_validation(validated_triple) == 1:
                    if len(validated_triple) == 3:
                        std_valid_triples.append(validated_triple)
                    else:
                        ext_valid_triples.append(validated_triple)
    return std_valid_triples, ext_valid_triples

# %%
std_triples, ext_triples = triple_analysis(triples)

# %%
def triple_mma_math(triples):
    """
    function that applies logic to separate triples that are supporting MMA Math deduction process and these which are not. 
    Moreover function is also calculating the score for each group.
    """
    valid_math = 0
    invalid_math = 0
    valid_math_triples = []
    invalid_math_triples = []
    for triple in triples:
        if triple['Rating'][0] == 2:
            if triple['Rating'][1] > triple['Rating'][2]:
                valid_math += 1
                valid_math_triples.append(triple)
            else:
                invalid_math += 1
                invalid_math_triples.append(triple)
        elif triple['Rating'][0] == 0:
            if triple['Rating'][1] < triple['Rating'][2]:
                valid_math += 1
                valid_math_triples.append(triple)
            else:
                invalid_math += 1
                invalid_math_triples.append(triple)
        else:
            print('WARNING: Invalid triple!')
            print(triple)
    
    if len(triples) == valid_math + invalid_math:
        print('Applying MMA math logic was successful')
    return valid_math, invalid_math, valid_math_triples, invalid_math_triples

def multiple_mma_math(triples):
    """
    function which is analogy to triple_mma_math function but applies to extended triples.
    """
    valid_math = 0
    invalid_math = 0
    valid_math_triples = []
    invalid_math_triples = []
    for triple in triples:
        truncated_triple = triple[1:]
        fighter_A = triple['Fighter'][0]
        fighter_B = triple['Opponent'][0]
        A_slice = truncated_triple[truncated_triple['Fighter'] == fighter_A]
        B_slice = truncated_triple[truncated_triple['Fighter'] == fighter_B]
        if triple['Rating'][0] == 2:
            if A_slice['Rating'].mean() > B_slice['Rating'].mean():
                if A_slice['Rating'].mean() >= 1:
                    valid_math += 1
                    valid_math_triples.append(triple)
            else:
                if B_slice['Rating'].mean() >= 1:
                    invalid_math += 1
                    invalid_math_triples.append(triple)
        elif triple['Rating'][0] == 0:
            if A_slice['Rating'].mean() < B_slice['Rating'].mean():
                if B_slice['Rating'].mean() >= 1:
                    valid_math += 1
                    valid_math_triples.append(triple)
            else:
                if A_slice['Rating'].mean() >= 1:
                    invalid_math += 1
                    invalid_math_triples.append(triple)
        else:
            print('WARNING: Invalid triple!')
            print(triple)
    
    if len(triples) == valid_math + invalid_math:
        print('Applying MMA math logic was successful')
    return valid_math, invalid_math, valid_math_triples, invalid_math_triples

# %%
valid_triple_score, invalid_triple_score, valid_math_triples, invalid_math_triples = triple_mma_math(std_triples)
# Out:
# Applying MMA math logic was successful

# %%
valid_triple_score
# Out:
# 152

# %%
invalid_triple_score
# Out:
# 135

# %%
add_triple_rating(ext_triples)

# %%
valid_multiple_score, invalid_multiple_score, valid_math_multiples, invalid_math_multiples =  multiple_mma_math(ext_triples)

# %%
valid_multiple_score
# Out:
# 75

# %%
invalid_multiple_score
# Out:
# 41

# %%
def test_random_triples():
    """
    additional function that is randomly showing triples in both categories - can be used for additional form of validation.
    """
    n = len(valid_math_triples)
    n2 = len(invalid_math_triples)
    ind1 = np.random.randint(1, n, size=5)
    ind2 = np.random.randint(1, n2, size=5)
    print('VALID MATH:')
    for indice in ind1:
        print(valid_math_triples[indice])
        print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
    print('------------------------')
    print('------------------------')
    print('------------------------')
    print('INVALID MATH:')
    for indice in ind2:
        print(invalid_math_triples[indice])
        print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')

        
def test_random_multiples():
    """
    additional function that is randomly showing multiples in both categories - can be used for additional form of validation.
    """
    n = len(valid_math_multiples)
    n2 = len(invalid_math_multiples)
    ind1 = np.random.randint(1, n, size=5)
    ind2 = np.random.randint(1, n2, size=5)
    print('VALID MATH:')
    for indice in ind1:
        print(valid_math_multiples[indice])
        print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
    print('------------------------')
    print('------------------------')
    print('------------------------')
    print('INVALID MATH:')
    for indice in ind2:
        print(invalid_math_multiples[indice])
        print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')

# %%
test_random_triples()
# Out:
# VALID MATH:
#          Fighter       Opponent Result Event_date  Rating
# 0    Demian Maia  Gunnar Nelson    win 2015-12-12       2
# 1    Demian Maia     Rick Story    win 2012-10-13       2
# 2  Gunnar Nelson     Rick Story   loss 2014-10-04       0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#                 Fighter              Opponent Result Event_date  Rating
# 0        Jan Blachowicz  Alexander Gustafsson   loss 2016-09-03       0
# 1        Jan Blachowicz           Jimi Manuwa   loss 2015-04-11       0
# 2  Alexander Gustafsson           Jimi Manuwa    win 2014-03-08       2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#                 Fighter              Opponent Result Event_date  Rating
# 0        Daniel Cormier  Alexander Gustafsson    win 2015-10-03       2
# 1        Daniel Cormier       Anthony Johnson    win 2015-05-23       2
# 2  Alexander Gustafsson       Anthony Johnson   loss 2015-01-24       0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#          Fighter       Opponent Result Event_date  Rating
# 0    Bobby Green  Drakkar Klose   loss 2018-12-15       0
# 1    Bobby Green  Lando Vannata   draw 2017-10-07       1
# 2  Drakkar Klose  Lando Vannata    win 2018-07-07       2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#           Fighter        Opponent Result Event_date  Rating
# 0  Donald Cerrone  Yancy Medeiros    win 2018-02-18       2
# 1  Donald Cerrone      Jim Miller    win 2014-07-16       2
# 2  Yancy Medeiros      Jim Miller   loss 2014-04-26       0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ------------------------
# ------------------------
# ------------------------
# INVALID MATH:
#           Fighter          Opponent Result Event_date  Rating
# 0  Corey Anderson       Ilir Latifi    win 2018-12-29       2
# 1  Corey Anderson  Ovince St. Preux   loss 2017-11-04       0
# 2     Ilir Latifi  Ovince St. Preux    win 2018-02-24       2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#               Fighter        Opponent Result Event_date  Rating
# 0  Joanna Jedrzejczyk  Rose Namajunas   loss 2018-04-07       0
# 1  Joanna Jedrzejczyk   Carla Esparza    win 2015-03-14       2
# 2      Rose Namajunas   Carla Esparza   loss 2014-12-12       0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#           Fighter        Opponent Result Event_date  Rating
# 0  Donald Cerrone     Al Iaquinta    win 2019-05-04       2
# 1  Donald Cerrone  Jorge Masvidal   loss 2017-01-28       0
# 2     Al Iaquinta  Jorge Masvidal    win 2015-04-04       2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#          Fighter       Opponent Result Event_date  Rating
# 0  Frank Camacho      Nick Hein    win 2019-06-01       2
# 1  Frank Camacho  Yusuke Kasuya   loss 2015-03-13       0
# 2      Nick Hein  Yusuke Kasuya    win 2015-09-26       2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#           Fighter        Opponent Result Event_date  Rating
# 0     Walt Harris  Alexey Oleynik    win 2019-07-20       2
# 1     Walt Harris   Jared Rosholt   loss 2013-11-30       0
# 2  Alexey Oleynik   Jared Rosholt    win 2014-11-22       2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
test_random_multiples()
# Out:
# VALID MATH:
#                 Fighter              Opponent Result Event_date  Rating
# 0     Katlyn Chookagian  Valentina Shevchenko   loss 2020-02-08       0
# 1     Katlyn Chookagian         Liz Carmouche   loss 2016-11-12       0
# 2  Valentina Shevchenko         Liz Carmouche    win 2019-08-10       2
# 3  Valentina Shevchenko         Liz Carmouche   loss 2010-09-30       0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#                 Fighter              Opponent Result Event_date  Rating
# 0           Jessica Eye  Valentina Shevchenko   loss 2019-06-08       0
# 1           Jessica Eye         Julianna Pena   loss 2015-10-03       0
# 2           Jessica Eye         Julianna Pena   loss 2015-10-03       0
# 3  Valentina Shevchenko         Julianna Pena    win 2017-01-28       2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#             Fighter           Opponent Result Event_date  Rating
# 0   Andrei Arlovski   Alistair Overeem   loss 2016-05-08       0
# 1   Andrei Arlovski  Sergei Kharitonov   loss 2011-02-12       0
# 2  Alistair Overeem  Sergei Kharitonov   loss 2007-09-17       0
# 3  Alistair Overeem  Sergei Kharitonov    win 2006-02-26       2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#            Fighter               Opponent Result Event_date  Rating
# 0  Claudia Gadelha           Randa Markos    win 2019-07-06       2
# 1  Claudia Gadelha  Karolina Kowalkiewicz    win 2017-06-03       2
# 2  Claudia Gadelha  Karolina Kowalkiewicz    win 2017-06-03       2
# 3     Randa Markos  Karolina Kowalkiewicz   loss 2015-12-19       0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#       Fighter          Opponent Result Event_date  Rating
# 0  Clay Guida        Jim Miller   loss 2019-08-03       0
# 1  Clay Guida  Charles Oliveira   loss 2018-06-09       0
# 2  Jim Miller  Charles Oliveira   loss 2018-12-15       0
# 3  Jim Miller  Charles Oliveira    win 2010-12-11       2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ------------------------
# ------------------------
# ------------------------
# INVALID MATH:
#            Fighter         Opponent Result Event_date  Rating
# 0    Nina Ansaroff  Claudia Gadelha    win 2018-12-08       2
# 1    Nina Ansaroff    Carla Esparza   loss 2010-12-10       0
# 2  Claudia Gadelha    Carla Esparza    win 2018-06-09       2
# 3  Claudia Gadelha    Carla Esparza    win 2018-06-09       2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#          Fighter       Opponent Result Event_date  Rating
# 0   Alexis Davis  Jennifer Maia   loss 2019-03-23       0
# 1   Alexis Davis  Liz Carmouche    win 2017-12-09       2
# 2   Alexis Davis  Liz Carmouche    win 2013-11-06       2
# 3  Jennifer Maia  Liz Carmouche   loss 2018-07-14       0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#          Fighter    Opponent Result Event_date  Rating
# 0  Melissa Gatto  Karol Rosa    win 2018-09-29       2
# 1  Melissa Gatto  Sidy Rocha   draw 2018-07-07       1
# 2  Melissa Gatto  Sidy Rocha   draw 2018-07-07       1
# 3     Karol Rosa  Sidy Rocha    win 2017-07-01       2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#              Fighter           Opponent Result Event_date  Rating
# 0         Holly Holm  Raquel Pennington    win 2020-01-18       2
# 1         Holly Holm        Miesha Tate   loss 2016-03-05       0
# 2         Holly Holm        Miesha Tate   loss 2016-03-05       0
# 3  Raquel Pennington        Miesha Tate    win 2016-11-12       2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#        Fighter       Opponent Result Event_date  Rating
# 0  Paul Felder     Dan Hooker   loss 2020-02-23       0
# 1  Paul Felder  Edson Barboza    win 2019-09-07       2
# 2  Paul Felder  Edson Barboza   loss 2015-07-25       0
# 3   Dan Hooker  Edson Barboza   loss 2018-12-15       0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# # Bayesian Analysis Part

# %% [markdown]
# **We will use Bayesian Reasoning by calculating Cumulative distribution function (CDF) for BETA distribution given the probability intervals.**
#
# Equation:
#
# # Beta(p; α,β) = (p^(α-1)) * ((1-p)^(β-1))/beta(α,β)
#
# where:
#
# ### p = the probability of an event
# ### α = how many times we observe an event we care about
# ### β = represent how many times event we didn't care about happen

# %%
def calculate_CDF(interval, a, b):
    """
    simple function that will calculate CDF given both variables alpha and beta + interval range
    """
    return beta.cdf(x=interval, a=a, b=b)[1] - beta.cdf(x=interval, a=a, b=b)[0]

# %% [markdown]
# ### Only Triples

# %%
valid_triple_score
# Out:
# 152

# %%
invalid_triple_score
# Out:
# 135

# %%
# probability of true rate lying in beetween 0.45 and 0.55
calculate_CDF([0.45, 0.55], valid_triple_score, invalid_triple_score)
# Out:
# 0.7515604629104752

# %%
# probability of true rate lying in beetween 0.40 and 0.60
calculate_CDF([0.40, 0.60], valid_triple_score, invalid_triple_score)
# Out:
# 0.9920237832019733

# %%
# finding 95% CI Interval

lower_bound = beta.ppf(0.025, valid_triple_score, invalid_triple_score)
upper_bound = beta.ppf(0.975, valid_triple_score, invalid_triple_score)

# %%
lower_bound
# Out:
# 0.47181944022812683

# %%
upper_bound
# Out:
# 0.5870229720578248

# %% [markdown]
# ### Triples + Extended Triples

# %%
all_triples_valid_score = valid_triple_score + valid_multiple_score
all_triples_invalid_score = invalid_triple_score + invalid_multiple_score

# %%
all_triples_valid_score
# Out:
# 227

# %%
all_triples_invalid_score
# Out:
# 176

# %%
# probability of true rate lying in beetween 0.45 and 0.55
calculate_CDF([0.45, 0.55], all_triples_valid_score, all_triples_invalid_score)
# Out:
# 0.29455961533343183

# %%
# probability of true rate lying in beetween 0.40 and 0.60
calculate_CDF([0.40, 0.60], all_triples_valid_score, all_triples_invalid_score)
# Out:
# 0.932257626514387

# %%
# finding 95% CI Interval

lower_bound = beta.ppf(0.025, all_triples_valid_score, all_triples_invalid_score)
upper_bound = beta.ppf(0.975, all_triples_valid_score, all_triples_invalid_score)

# %%
lower_bound
# Out:
# 0.5146401052815123

# %%
upper_bound
# Out:
# 0.6113158328668202

# %% [markdown]
# # Data Visualization Stage

# %%
from graphviz import Graph
from graphviz import Digraph

# %% [markdown]
# ### Using graphviz to create Decission Diagraph for Data Processing in therein project

# %%
dot = Digraph('process', filename='process.gv', node_attr={'color': 'lightblue2', 'style': 'filled'})

# %%
dot.node('A', 'List of all the UFC Fighters in the current roster:    Has this fighter fought any other fighter on the UFC roster?')
dot.node('x', 'YES')
dot.node('y', 'NO')
dot.edges(['Ax', 'Ay'])

dot.node('B', 'Pairs of fighters from UFC roster that have fought each other:    Do they share common opponent?')
dot.edges(['xB'])
dot.node('z', 'YES')
dot.node('w', 'NO')
dot.edges(['Bz', 'Bw'])

dot.node('C', 'Pairs of UFC fighters that share a common opponent:    Have they fought this opponent before they have fought each other?')
dot.edges(['zC'])
dot.node('o', 'YES')
dot.node('p', 'NO')
dot.edges(['Co', 'Cp'])

dot.node('D', 'Include the result in the analysis!')
dot.node('E', 'Exclude the result from the analysis!')
dot.edges(['oD'])
dot.edges(['pE'])

# %%
dot.render()
# Out:
# 'process.gv.pdf'

# %% [markdown]
# ### Generating Grap Visualization for Triples

# %%
def create_triple_graph(t, n):
    """
    function that creates diagraph from triple.
    """
    dot = Digraph(f'triple{n}', filename=f'triple{n}.gv', node_attr={'color': 'lightblue2', 'style': 'filled'})
    dot.node('A', t['Fighter'][0])
    dot.node('B', t['Opponent'][0])
    dot.node('C', t['Opponent'][1])
    dot.edge('A', 'B', label=t['Result'][0], constraint='false')
    dot.edge('A', 'C', label=t['Result'][1])
    dot.edge('B', 'C', label=t['Result'][2])
    dot.render()

# %%
n = 1
for triple in valid_math_triples:
    create_triple_graph(triple, n)
    n += 1

# %%
n = 1
for triple in invalid_math_triples:
    create_triple_graph(triple, n)
    n += 1

# %% [markdown]
# # Conclusion

# %% [markdown]
# With a high degree of confidence we can say that the true rate of MMA math deduction accuracy lies between **48% - 58%** percent for data containing only triples and between **51%-61%** for combined data, which is either hardly at all, or just slightly above random outcome.
